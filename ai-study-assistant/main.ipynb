# %% [markdown]
# # AI Study Assistant Agent
#
# This notebook provides a simple interface to interact with the **AI Study Assistant Agent** defined in this repository.
#
# You can run the cells below and chat with the agent in a loop.
#
# > ⚠️ By default, the agent uses a **dummy LLM response**.
# To plug in a real model (OpenAI, Gemini, etc.), edit `llm.py`.

# %%
from agent import run_agent

print("AI Study Assistant. Type 'exit' to quit.\n")

while True:
    user_msg = input("You: ")
    if user_msg.lower() in ["exit", "quit"]:
        print("Goodbye! 👋")
        break
    reply = run_agent(user_msg)
    print("\nAssistant:\n", reply, "\n")
